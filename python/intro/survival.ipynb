# %%
from bravado.client import SwaggerClient

cbioportal = SwaggerClient.from_url('https://www.cbioportal.org/api/api-docs',
                                config={"validate_requests":False,"validate_responses":False})
print(cbioportal)
# Out:
# SwaggerClient(https://www.cbioportal.org/api)

# %% [markdown]
# ### Fetch Clinical Data via POST

# %%
request_json = {"attributeIds":["OS_STATUS","OS_MONTHS","DFS_STATUS","DFS_MONTHS","DSS_STATUS","DSS_MONTHS","PFS_STATUS","PFS_MONTHS"],"identifiers":[{"entityId":"TCGA-BF-AAP0","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2J7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JK","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JP","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3C1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3C3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3C6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3C7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3CB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3CE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3MO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3MR","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3MU","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51J","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51N","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A5GN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A5GR","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A5GS","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A5GU","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GJ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GS","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GV","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A148","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A1JX","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A3Z3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A6E9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A6EG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1HW","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1HY","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I0","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I2","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A3F5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A3F8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A95W","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A5UN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A17Y","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A183","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A20B","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A20F","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A20H","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29A","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29C","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29E","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29H","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29M","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29P","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29T","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29W","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2A6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GS","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GT","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2M5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2M6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2M7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2M8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2ME","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MK","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MP","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AF","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3J3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3J4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3JB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3JE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A198","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19B","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19C","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19E","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19G","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19H","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19J","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19M","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19O","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19P","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19Q","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19S","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A2NC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A2ND","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A2NG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A3PL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A42K","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A42L","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A44A","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A729","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A7UA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A8YE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1YX","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1YY","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1Z7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZF","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZM","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZR","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZS","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4F8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4FB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FW-A3TV","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GF-A4EO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GF-A6C8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GF-A6C9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A262","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A265","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A26A","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A4U7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A4U8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A9SD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-HR-A2OH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-LH-A9QB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-OD-A75X","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-QB-A6FS","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-AA1Q","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-AA1R","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-AA1W","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-AA21","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8K5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8K6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZQ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZT","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZX","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-AAA0","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-AAA4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-YD-A9TB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-Z2-A8RT","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-Z2-AA3V","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-3N-A9WB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-3N-A9WC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-3N-A9WD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1Q8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1QA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A1QB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2J6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2J8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2J9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JF","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A2JO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3BZ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3C8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3CC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3CF","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3ML","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A3MV","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51E","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51F","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51G","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51H","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51K","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51R","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A51T","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A5GL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A5GO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GI","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GK","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GM","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GP","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GQ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D3-A8GR","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A149","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A1JW","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A1X3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A3Z1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A4Z6","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A6EA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-D9-A6EC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1HV","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1I1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1IA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1IB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A1IC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A3F3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A95V","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A95X","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A95Y","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-DA-A95Z","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A44Q","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A44R","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A5KH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A5SG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A5SH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A5UL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EB-A6L9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A17X","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A17Z","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A180","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A181","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A182","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A184","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A185","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A20C","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A20I","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29B","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29D","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29G","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29L","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29N","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29Q","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29R","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29S","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29V","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A29X","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2A0","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2A1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2A2","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2A5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GI","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GJ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GK","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GM","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GP","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GR","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2GU","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MF","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MI","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MJ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2ML","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MM","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MQ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MR","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MS","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MT","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A2MU","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3AE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3J5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3J7","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3J8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3JA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3JD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3JH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-EE-A3JI","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A193","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A195","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A197","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A199","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19A","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19D","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19F","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19L","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19N","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19T","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A19W","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A1A1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A2NE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A2NF","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A2NH","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A3ES","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A3ET","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-ER-A3EV","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A3YN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A3YO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A69P","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A7U8","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A7U9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A8YC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FR-A8YD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1YW","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1Z0","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1Z3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1Z4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZB","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZE","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZJ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZK","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZP","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZQ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZT","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZU","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZW","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZY","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A1ZZ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4F0","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4F4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4F5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4F9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4FC","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FS-A4FD","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FW-A3I3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FW-A3R5","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FW-A3TU","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-FW-A5DY","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GF-A3OT","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A264","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A266","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A267","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A268","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A26D","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A4U3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A4U4","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A4U9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A8LK","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-GN-A8LL","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-HR-A2OG","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-QB-AA9O","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-RP-A690","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-RP-A693","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-RP-A694","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-RP-A695","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-RP-A6K9","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-A824","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-A825","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-A828","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-AA1O","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-W3-AA1V","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8JZ","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8K1","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZM","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZN","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZO","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-A8ZY","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-AA9Y","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-WE-AAA3","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-YD-A89C","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-YD-A9TA","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-YG-AA3O","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-YG-AA3P","studyId":"skcm_tcga_pan_can_atlas_2018"},{"entityId":"TCGA-Z2-AA3S","studyId":"skcm_tcga_pan_can_atlas_2018"}]}

clinical_data = cbioportal.Clinical_Data.fetchClinicalDataUsingPOST(
    clinicalDataMultiStudyFilter=request_json,
    clinicalDataType='PATIENT').result()
#print(clinical_data)

# %% [markdown]
# ### Fetch molecular profile data

# %%
request_json = {"studyIds":["skcm_tcga_pan_can_atlas_2018"]}

#molecular_profiles = cbioportal.Mutations.getMutationsInMolecularProfileBySampleListIdUsingGET(
#)


#molecular_profiles = cbioportal.Molecular_Profiles.fetchMolecularProfilesUsingPOST(
#    molecularProfileFilter=request_json).result()

#print(molecular_profiles)
# Out:
# [MolecularProfile(datatype='LOG2-VALUE', description='Protein expression measured by reverse-phase protein array', genericAssayType=None, molecularAlterationType='PROTEIN_LEVEL', molecularProfileId='skcm_tcga_pan_can_atlas_2018_rppa', name='Protein expression (RPPA)', pivotThreshold=None, showProfileInAnalysisTab=False, sortOrder=None, study=None, studyId='skcm_tcga_pan_can_atlas_2018'), MolecularProfile(datatype='Z-SCORE', description='Protein expression, measured by reverse-phase protein array, Z-scores', genericAssayType=None, molecularAlterationType='PROTEIN_LEVEL', molecularProfileId='skcm_tcga_pan_can_atlas_2018_rppa_Zscores', name='Protein expression z-scores (RPPA)', pivotThreshold=None, showProfileInAnalysisTab=True, sortOrder=None, study=None, studyId='skcm_tcga_pan_can_atlas_2018'), MolecularProfile(datatype='DISCRETE', description='Putative copy-number from GISTIC 2.0. Values: -2 = homozygous deletion; -1 = hemizygous deletion; 0 = neutral / no change; 1 = gain; 2 = high 
# ...

# %%
import pandas as pd

mdf = pd.DataFrame.from_dict([
    dict(
        {k:getattr(m,k) for k in m})
    for m in molecular_profiles
])

# %%
mdf
# Out:
#       datatype                                        description  \
# 0   LOG2-VALUE  Protein expression measured by reverse-phase p...
# 1      Z-SCORE  Protein expression, measured by reverse-phase ...
# 2     DISCRETE  Putative copy-number from GISTIC 2.0. Values: ...
# 3   CONTINUOUS  mRNA Expression, RSEM (Batch normalized from I...
# 4      Z-SCORE  mRNA expression z-scores (RNA Seq V2 RSEM) com...
# 5   LOG2-VALUE  Log2 copy-number values for each gene (from Af...
# 6          MAF  Mutation data from whole exome sequencing of 4...
# 7       FUSION                                           Fusions.
# 8      Z-SCORE  Log-transformed mRNA expression z-scores compa...
# 9  LIMIT-VALUE  Microbial Signatures (log-cpm) from whole-tran...
#
#        genericAssayType molecularAlterationType  \
# 0                  None           PROTEIN_LEVEL
# 1                  None           PROTEIN_LEVEL
# 2                  None  COPY_NUMBER_ALTERATION
# ...

# %% [markdown]
# ### Make a pandas data frame

# %%
import pandas as pd

df = pd.DataFrame.from_dict([
    dict(
        {k:getattr(c,k) for k in c})
    for c in clinical_data
])
df
# Out:
#      clinicalAttribute clinicalAttributeId     patientId sampleId  \
# 0                 None          DSS_MONTHS  TCGA-3N-A9WB     None
# 1                 None          DSS_STATUS  TCGA-3N-A9WB     None
# 2                 None           OS_MONTHS  TCGA-3N-A9WB     None
# 3                 None           OS_STATUS  TCGA-3N-A9WB     None
# 4                 None          PFS_MONTHS  TCGA-3N-A9WB     None
# ...                ...                 ...           ...      ...
# 2102              None          DSS_STATUS  TCGA-Z2-AA3V     None
# 2103              None           OS_MONTHS  TCGA-Z2-AA3V     None
# 2104              None           OS_STATUS  TCGA-Z2-AA3V     None
# 2105              None          PFS_MONTHS  TCGA-Z2-AA3V     None
# 2106              None          PFS_STATUS  TCGA-Z2-AA3V     None
#
#                            studyId  \
# 0     skcm_tcga_pan_can_atlas_2018
# 1     skcm_tcga_pan_can_atlas_2018
# 2     skcm_tcga_pan_can_atlas_2018
# ...

# %%
clinical_data[0]
# Out:
# ClinicalData(clinicalAttribute=None, clinicalAttributeId='DSS_MONTHS', patientId='TCGA-3N-A9WB', sampleId=None, studyId='skcm_tcga_pan_can_atlas_2018', uniquePatientKey='VENHQS0zTi1BOVdCOnNrY21fdGNnYV9wYW5fY2FuX2F0bGFzXzIwMTg', uniqueSampleKey=None, value='17.029950357')

# %%
import plotly.express as px

fig = px.scatter(df, x="value", y="sepal_length")
fig.show()
# Out:
#       datatype                                        description  \
# 0   LOG2-VALUE  Protein expression measured by reverse-phase p...
# 1      Z-SCORE  Protein expression, measured by reverse-phase ...
# 2     DISCRETE  Putative copy-number from GISTIC 2.0. Values: ...
# 3   CONTINUOUS  mRNA Expression, RSEM (Batch normalized from I...
# 4      Z-SCORE  mRNA expression z-scores (RNA Seq V2 RSEM) com...
# 5   LOG2-VALUE  Log2 copy-number values for each gene (from Af...
# 6          MAF  Mutation data from whole exome sequencing of 4...
# 7       FUSION                                           Fusions.
# 8      Z-SCORE  Log-transformed mRNA expression z-scores compa...
# 9  LIMIT-VALUE  Microbial Signatures (log-cpm) from whole-tran...
#
#        genericAssayType molecularAlterationType  \
# 0                  None           PROTEIN_LEVEL
# 1                  None           PROTEIN_LEVEL
# 2                  None  COPY_NUMBER_ALTERATION
# ...

# %%
overall_survival = df.loc[(df.clinicalAttributeId == "OS_MONTHS") | (df.clinicalAttributeId == "OS_STATUS")]
overall_survival
# Out:
#      clinicalAttribute clinicalAttributeId     patientId sampleId  \
# 2                 None           OS_MONTHS  TCGA-3N-A9WB     None
# 3                 None           OS_STATUS  TCGA-3N-A9WB     None
# 8                 None           OS_MONTHS  TCGA-3N-A9WC     None
# 9                 None           OS_STATUS  TCGA-3N-A9WC     None
# 14                None           OS_MONTHS  TCGA-3N-A9WD     None
# ...                ...                 ...           ...      ...
# 2092              None           OS_STATUS  TCGA-Z2-A8RT     None
# 2097              None           OS_MONTHS  TCGA-Z2-AA3S     None
# 2098              None           OS_STATUS  TCGA-Z2-AA3S     None
# 2103              None           OS_MONTHS  TCGA-Z2-AA3V     None
# 2104              None           OS_STATUS  TCGA-Z2-AA3V     None
#
#                            studyId  \
# 2     skcm_tcga_pan_can_atlas_2018
# 3     skcm_tcga_pan_can_atlas_2018
# 8     skcm_tcga_pan_can_atlas_2018
# ...

# %%
disease_specific_survival = df.loc[(df.clinicalAttributeId == "DSS_MONTHS") | (df.clinicalAttributeId == "DSS_STATUS")]
disease_specific_survival
# Out:
#      clinicalAttribute clinicalAttributeId     patientId sampleId  \
# 0                 None          DSS_MONTHS  TCGA-3N-A9WB     None
# 1                 None          DSS_STATUS  TCGA-3N-A9WB     None
# 6                 None          DSS_MONTHS  TCGA-3N-A9WC     None
# 7                 None          DSS_STATUS  TCGA-3N-A9WC     None
# 12                None          DSS_MONTHS  TCGA-3N-A9WD     None
# ...                ...                 ...           ...      ...
# 2090              None          DSS_STATUS  TCGA-Z2-A8RT     None
# 2095              None          DSS_MONTHS  TCGA-Z2-AA3S     None
# 2096              None          DSS_STATUS  TCGA-Z2-AA3S     None
# 2101              None          DSS_MONTHS  TCGA-Z2-AA3V     None
# 2102              None          DSS_STATUS  TCGA-Z2-AA3V     None
#
#                            studyId  \
# 0     skcm_tcga_pan_can_atlas_2018
# 1     skcm_tcga_pan_can_atlas_2018
# 6     skcm_tcga_pan_can_atlas_2018
# ...

# %%
progression_free_survival = df.loc[(df.clinicalAttributeId == "PFS_MONTHS") | (df.clinicalAttributeId == "PFS_STATUS")]
progression_free_survival
# Out:
#      clinicalAttribute clinicalAttributeId     patientId sampleId  \
# 4                 None          PFS_MONTHS  TCGA-3N-A9WB     None
# 5                 None          PFS_STATUS  TCGA-3N-A9WB     None
# 10                None          PFS_MONTHS  TCGA-3N-A9WC     None
# 11                None          PFS_STATUS  TCGA-3N-A9WC     None
# 16                None          PFS_MONTHS  TCGA-3N-A9WD     None
# ...                ...                 ...           ...      ...
# 2094              None          PFS_STATUS  TCGA-Z2-A8RT     None
# 2099              None          PFS_MONTHS  TCGA-Z2-AA3S     None
# 2100              None          PFS_STATUS  TCGA-Z2-AA3S     None
# 2105              None          PFS_MONTHS  TCGA-Z2-AA3V     None
# 2106              None          PFS_STATUS  TCGA-Z2-AA3V     None
#
#                            studyId  \
# 4     skcm_tcga_pan_can_atlas_2018
# 5     skcm_tcga_pan_can_atlas_2018
# 10    skcm_tcga_pan_can_atlas_2018
# ...

# %%
import plotly.express as px

# TODO Survival Function!

fig = px.scatter(overall_survival, x="value", y="sepal_length")
fig.show()
